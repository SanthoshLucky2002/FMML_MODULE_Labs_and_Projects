# %% [markdown]
# <a href="https://colab.research.google.com/github/SanthoshLucky2002/FMML_MODULE_Labs_and_Projects/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-04-11 03:33:31--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.108.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   109MB/s    in 0.6s
#
# 2024-04-11 03:33:32 (109 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 25036  1504.02531v2  Efficient Human Epithelial-2 (HEp-2) cell imag...    cs
# 67     1509.06664v4  While most approaches to automatically recogni...    cs
# 31290  1802.09745v1  Designing a scheme that can achieve a good per...    cs
# 28172  1705.08374v1  We present a powerful method to extract per-po...    cs
# 29190  1708.06822v2  Ingestible wireless capsule endoscopy is an em...    cs
# ...             ...                                                ...   ...
# 8440   1608.00220v1  We present and evaluate the capacity of a deep...    cs
# 22068   1409.7134v2  Diffusion-weighted magnetic resonance imaging ...  stat
# 12190  1710.03971v1  For many algorithms, parameter tuning remains ...  stat
# 17415  1711.00513v2  For machine translation to tackle discourse ph...    cs
# 21588   1106.0474v1  We propose a restricted collapsed draw (RCD) s...  stat
#
#                                                    title  year  \
# 25036  HEp-2 Cell Image Classification with Deep Conv...  2015
# 67      Reasoning about Entailment with Neural Attention  2015
# 31290  ReHAR: Robust and Efficient Human Activity Rec...  2018
# 28172  Classification of Aerial Photogrammetric 3D Po...  2017
# 29190  Deep EndoVO: A Recurrent Convolutional Neural ...  2017
# ...                                                  ...   ...
# 8440   Learning Robust Features using Deep Learning f...  2016
# 22068  Deconvolution of High-Dimensional Mixtures via...  2014
# 12190  Adaptive multi-penalty regularization based on...  2017
# 17415  Evaluating Discourse Phenomena in Neural Machi...  2017
# 21588  Restricted Collapsed Draw: Accurate Sampling f...  2011
#
#                                                 keywords
# 25036  [efficient, epithelial, classification, facili...
# 67     [approaches, automatically, recognizing, entai...
# 31290  [designing, performance, predicting, activitie...
# 28172  [aerialphotogrammetry, important, environmenta...
# 29190  [ingestible, endoscopy, minimally, diagnostic,...
# ...                                                  ...
# 8440   [automatically, challenging, manifestations, e...
# 22068  [diffusion, resonance, tractography, structure...
# 12190  [algorithms, parameter, challenging, infeasibl...
# 17415  [translation, discourse, phenomena, sentential...
# 21588  [restricted, collapsed, simultaneous, hierarch...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 25036    [efficient, epithelial, classification, facili...
# 67       [approaches, automatically, recognizing, entai...
# 31290    [designing, performance, predicting, activitie...
# 28172    [aerialphotogrammetry, important, environmenta...
# 29190    [ingestible, endoscopy, minimally, diagnostic,...
#                                ...
# 17206    [communication, consequence, different, societ...
# 21503    [simulated, annealing, approaching, optimizati...
# 37837    [uncertainty, variability, considering, deriva...
# 10503    [telemonitoring, important, telemedicine, tele...
# 22410    [clustering, important, unsupervised, statisti...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8888 words.
# Out of those 4577 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c02b9e28-083d-487c-b8d5-f556fc99e6f9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c02b9e28-083d-487c-b8d5-f556fc99e6f9")) {                    Plotly.newPlot(                        "c02b9e28-083d-487c-b8d5-f556fc99e6f9",                        [{"x":["epithelial","framework","established","automatic","different","laboratory","literature","excellent","efficient","elaborates","utilizing","discusses","systematically","augmentation","important","experiments","demonstrates","convolutional","diagnosis","recognition","benchmark","intensive","competition","effectively","facilitate","attracted","desirable","autoimmune","components","efficiency","adaptability","classification","attention","outperform","entailment","relations","encourages","outperforms","sentences","automatically","furthermore","capabilities","performance","differentiable","demonstrating","qualitative","reasoning","determine","recognizing","mechanism","similarity","engineered","pipelines","processing","classifiers","entailments","substantial","classifier","employing","approaches","representations","ucfsports","designing","representation","magnitude","computation","activities","generated","prediction","challenging","predicting","corresponding","meaningful","basketball","experimental","generalize","containing","understanding","incorporating","geometric","information","densities","significant","exclusively","environmental","detecting","modelling","photogrammetric","photogrammetry","techniques","accuracies","monocular","companies","inspection","progresses","estimation","respectively","extraction","inference","pathologies","recurrent","functionality","application","minimally","diagnostic","evaluations","translational","converting","trajectories","controlled","rotational","endoscopy","operations","detection","intuitive","technology","estimates","following","supervision","relationships","situations","subproblems","supervised","plausible","baselines","particular","throughout","algorithms","consensus","computing","qualitatively","compromising","selection","identifying","technique","computational","clustering","considering","diversity","generating","frequency","judiciously","addresses","overheads","unnecessary","prioritize","representative","intelligence","partitions","transformations","statistical","invariances","visualizing","incorporate","introduce","explicitly","generative","architecture","rotations","adversarial","translations","parametrize","probability","initialized","essential","incapable","intriguingly","distribution","condition","achieving","exponential","analytically","initialization","vanishing","dependence","orthogonal","gradients","dramatically","concentrate","consideration","demonstrate","nonlinear","controlling","empirically","nonlinearity","consistently","explosion","sigmoidal","dynamical","integrate","transform","resurgence","appealing","localization","illumination","assumption","investigation","popularity","consistency","environments"],"y":[2,545,53,202,755,12,126,29,416,3,34,20,27,25,357,611,53,416,62,404,223,29,39,125,40,25,36,1,91,170,3,527,173,100,14,90,11,227,58,210,173,39,875,22,27,51,136,75,38,101,156,7,16,328,129,3,44,167,48,409,214,2,50,369,57,134,40,168,249,267,91,126,55,1,351,42,54,152,51,63,724,7,232,6,13,76,46,3,2,375,24,17,6,6,6,216,105,147,202,2,149,10,237,7,21,43,2,4,33,42,7,2,71,362,37,53,78,93,52,75,43,5,200,34,49,256,26,618,10,120,25,7,177,77,264,255,159,69,35,84,58,2,57,6,6,4,32,87,12,42,154,5,10,62,357,71,95,255,7,91,23,2,157,8,80,6,1,210,43,66,41,10,24,12,26,24,27,16,6,34,567,61,11,75,5,45,10,2,21,42,62,1,19,62,37,57,40,22,59,81],"type":"bar"},{"x":["epithelial","framework","established","automatic","different","laboratory","li ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4577,), (4577, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.805

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Polarity</span> <span style='background-color:rgba(0, 255, 0, 0.5569892473118281);'>detection</span> <span style=''>movie</span> <span style=''>reviews</span> <span style=''>in</span> <span style=''>hindi</span> <span style=''>language</span> <br/><br/><span style=''>Nowadays</span> <span style=''>peoples</span> <span style=''>are</span> <span style=''>actively</span> <span style=''>involved</span> <span style=''>in</span> <span style=''>giving</span> <span style=''>comments</span> <span style=''>and</span> <span style=''>reviews</span> <span style=''>on</span> <span style=''>social</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>networking</span> <span style=''>websites</span> <span style=''>and</span> <span style=''>other</span> <span style=''>websites</span> <span style=''>like</span> <span style=''>shopping</span> <span style=''>websites</span> <span style=''>news</span> <span style=''>websites</span> <span style=''>etc</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>people</span> <span style=''>everyday</span> <span style=''>share</span> <span style=''>their</span> <span style=''>opinion</span> <span style=''>on</span> <span style=''>the</span> <span style=''>web</span> <span style=''>results</span> <span style=''>is</span> <span style=''>a</span> <span style=''>large</span> <span style=''>number</span> <span style=''>of</span> <span style=''>user</span> <span style=''>data</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.37681159420289856);'>collected</span> <span style=''>users</span> <span style=''>also</span> <span style=''>find</span> <span style=''>it</span> <span style=''>trivial</span> <span style=''>task</span> <span style=''>to</span> <span style=''>read</span> <span style=''>all</span> <span style=''>the</span> <span style=''>reviews</span> <span style=''>and</span> <span style=''>then</span> <span style=''>reached</span> <span style=''>into</span> <span style=''>the</span> <span style=''>decision</span> <span style=''>It</span> <span style=''>would</span> <span style=''>be</span> <span style=''>better</span> <span style=''>if</span> <span style=''>these</span> <span style=''>reviews</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.47619047619047616);'>classified</span> <span style=''>into</span> <span style=''>some</span> <span style=''>category</span> <span style=''>so</span> <span style=''>that</span> <span style=''>the</span> <span style=''>user</span> <span style=''>finds</span> <span style=''>it</span> <span style=''>easier</span> <span style=''>to</span> <span style=''>read</span> <span style=''>Opinion</span> <span style=''>Mining</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.5238095238095237);'>Sentiment</span> <span style=''>Analysis</span> <span style=''>is</span> <span style=''>a</span> <span style=''>natural</span> <span style=''>language</span> <span style='background-color:rgba(0, 255, 0, 0.4741573033707865);'>processing</span> <span style=''>task</span> <span style=''>that</span> <span style=''>mines</span> <span style='background-color:rgba(0, 255, 0, 0.3247941445562672);'>information</span> <span style=''>from</span> <span style=''>various</span> <span style=''>text</span> <span style=''>forms</span> <span style=''>such</span> <span style=''>as</span> <span style=''>reviews</span> <span style=''>news</span> <span style=''>and</span> <span style=''>blogs</span> <span style=''>and</span> <span style=''>classify</span> <span style=''>them</span> <span style=''>on</span> <span style=''>the</span> <span style=''>basis</span> <span style=''>of</span> <span style=''>their</span> <span style=''>polarity</span> <span style=''>as</span> <span style=''>positive</span> <span style=''>negative</span> <span style=''>or</span> <span style=''>neutral</span> <span style=''>But</span> <span style=''>from</span> <span style=''>the</spa ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Sparse</span> <span style=''>and</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>large</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrices</span> <span style=''>using</span> <span style=''>biharmonic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <br/><br/><span style='background-color:rgba(0, 255, 0, 0.3);'>Symmetric</span> <span style=''>matrices</span> <span style=''>are</span> <span style=''>widely</span> <span style=''>used</span> <span style=''>in</span> <span style=''>machine</span> <span style=''>learning</span> <span style=''>problems</span> <span style=''>such</span> <span style=''>as</span> <span style=''>kernel</span> <span style=''>machines</span> <span style=''>and</span> <span style=''>manifold</span> <span style=''>learning</span> <span style=''>Using</span> <span style=''>large</span> <span style=''>datasets</span> <span style=''>often</span> <span style=''>requires</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computing</span> <span style=''>low</span> <span style=''>rank</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximations</span> <span style=''>of</span> <span style=''>these</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>symmetric</span> <span style=''>matrices</span> <span style=''>so</span> <span style=''>that</span> <span style=''>they</span> <span style=''>fit</span> <span style=''>in</span> <span style=''>memory</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>method</span> <span style=''>based</span> <span style=''>on</span> <span style=''>biharmonic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>for</span> <span style=''>low</span> <span style=''>rank</span> <span style=''>matrix</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximation</span> <span style=''>The</span> <span style=''>method</span> <span style=''>exploits</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style=''>of</span> <span style=''>the</span> <span style=''>data</span> <span style=''>manifold</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interpolation</span> <span style=''>operator</span> <span style=''>that</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximates</span> <span style=''>values</span> <span style=''>using</span> <span style=''>a</span> <span style=''>subset</span> <span style=''>of</span> <span style=''>randomly</span> <span style=''>selected</span> <span style=''>landmark</span> <span style=''>points</span> <span style=''>This</span> <span style=''>operator</span> <span style=''>is</span> <span style=''>readily</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sparsified</span> <span style=''>reducing</span> <span style=''>memory</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>requirements</span> <span style=''>by</span> <span style=''>at</span> <span style=''>least</span> <span style=''>two</span> <span style=''>orders</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>magnitude</span> <span style=''>without</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>significant</span> <span style=''>loss</span> <span style=''>in</span> <span style=''>accuracy</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>our</span> <span style=''>method</span> <span style=''>can</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approximate</span> <span style=''>very</span> <span sty ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3247941445562672);'>Information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Theoretic</span> <span style=''>Learning</span> <span style=''>with</span> <span style='background-color:rgba(255, 0, 0, 0.7333333333333334);'>Infinitely</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>Divisible</span> <span style=''>Kernels</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>develop</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 0.3247941445562672);'>information</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>theoretic</span> <span style=''>learning</span> <span style=''>based</span> <span style=''>on</span> <span style='background-color:rgba(255, 0, 0, 0.7333333333333334);'>infinitely</span> <span style='background-color:rgba(255, 0, 0, 0.33333333333333337);'>divisible</span> <span style=''>matrices</span> <span style=''>We</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>formulate</span> <span style=''>an</span> <span style=''>entropy</span> <span style=''>like</span> <span style='background-color:rgba(255, 0, 0, 0.3153153153153153);'>functional</span> <span style=''>on</span> <span style=''>positive</span> <span style=''>definite</span> <span style=''>matrices</span> <span style=''>based</span> <span style=''>on</span> <span style=''>Renyis</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>axiomatic</span> <span style='background-color:rgba(0, 255, 0, 0.4035087719298245);'>definition</span> <span style=''>of</span> <span style=''>entropy</span> <span style=''>and</span> <span style=''>examine</span> <span style=''>some</span> <span style=''>key</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>properties</span> <span style=''>of</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3153153153153153);'>functional</span> <span style=''>that</span> <span style=''>lead</span> <span style=''>to</span> <span style=''>the</span> <span style=''>concept</span> <span style=''>of</span> <span style=''>infinite</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>divisibility</span> <span style=''>The</span> <span style=''>proposed</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>formulation</span> <span style=''>avoids</span> <span style=''>the</span> <span style=''>plug</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimation</span> <span style=''>of</span> <span style=''>density</span> <span style=''>and</span> <span style=''>brings</span> <span style=''>along</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3768656716417911);'>representation</span> <span style=''>power</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.6417910447761195);'>reproducing</span> <span style=''>kernel</span> <span style=''>Hilbert</span> <span style=''>spaces</span> <span style=''>As</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>application</span> <span style=''>example</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>supervised</span> <span style=''>metric</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>using</span> <span style=''>a</span> <span style=''>matrix</span> <span style=''>based</span> <span style=''>analogue</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditional</span> <span style=''>entropy</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>achieving</span> <span style=''>results</span> <span style='ba ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Grafting</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Combinatorial</span> <span style=''>Boolean</span> <span style=''>Model</span> <span style=''>using</span> <span style=''>Frequent</span> <span style=''>Itemset</span> <span style=''>Mining</span> <br/><br/><span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduces</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinatorial</span> <span style=''>Boolean</span> <span style=''>model</span> <span style=''>(CBM)</span> <span style=''>which</span> <span style=''>is</span> <span style=''>defined</span> <span style=''>as</span> <span style=''>the</span> <span style=''>class</span> <span style=''>of</span> <span style=''>linear</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>combinations</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conjunctions</span> <span style=''>of</span> <span style=''>Boolean</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>This</span> <span style=''>paper</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>addresses</span> <span style=''>the</span> <span style=''>issue</span> <span style=''>of</span> <span style=''>learning</span> <span style=''>CBM</span> <span style=''>from</span> <span style=''>labeled</span> <span style=''>data</span> <span style=''>CBM</span> <span style=''>is</span> <span style=''>of</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>knowledge</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>interpretability</span> <span style=''>but</span> <span style=''>naive</span> <span style=''>learning</span> <span style=''>of</span> <span style=''>it</span> <span style=''>requires</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>exponentially</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>computation</span> <span style=''>time</span> <span style=''>with</span> <span style=''>respect</span> <span style=''>to</span> <span style=''>data</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dimension</span> <span style=''>and</span> <span style=''>sample</span> <span style=''>size</span> <span style=''>To</span> <span style=''>overcome</span> <span style=''>this</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>computational</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>difficulty</span> <span style=''>we</span> <span style=''>propose</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>GRAB</span> <span style=''>(GRAfting</span> <span style=''>for</span> <span style=''>Boolean</span> <span style=''>datasets)</span> <span style=''>which</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficiently</span> <span style=''>learns</span> <span style=''>CBM</span> <span style=''>within</span> <span style=''>the</span> <span style=''>L</span> <span style=''>1</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>regularized</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>The</span> <span style=''>key</span> <span style=''>idea</span> <span style=''>of</span> <span style=''>GRAB</span> <span style=''>is</span> <span style=''>to</span> <span style=''>reduce</span> <span style=''>the</span> <span style=''>loss</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>minimization</span> <span style=''>problem</span> <span style=''>to</span> <span style=''>the</span> <span style=''>weighted</span> <span style=''>frequent</span> <span style=''>itemset</span> <span style=''>mining</span> <span style=''>in</span> <span style=''>which</span> <span style=''>freq ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	automatic (0.07271418286537078)
# 	representation (0.132829373650108)
# 	segmentation (0.0687544996400288)
# 	architecture (0.091792656587473)
# 	processing (0.11807055435565154)
# 	information (0.2606191504679626)
# 	detection (0.1303095752339813)
# 	different (0.27177825773938086)
# 	convolutional (0.14974802015838734)
# 	recognition (0.14542836573074155)
#
# Some Statistics words are:
# 	variables (0.1280909990108803)
# 	stochastic (0.13254203758654798)
# 	estimation (0.17359050445103857)
# 	theoretical (0.1543026706231454)
# 	statistical (0.15380811078140455)
# 	algorithm (0.38031651829871416)
# 	distribution (0.1785361028684471)
# 	dimensional (0.18298714144411474)
# 	inference (0.19881305637982197)
# 	regression (0.17754698318496537)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1a8fe7cb-f852-419c-8ed9-a06a89eb4968" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a8fe7cb-f852-419c-8ed9-a06a89eb4968")) {                    Plotly.newPlot(                        "1a8fe7cb-f852-419c-8ed9-a06a89eb4968",                        [{"x":["epithelial","framework","established","automatic","different","laboratory","literature","excellent","efficient","elaborates","utilizing","discusses","systematically","augmentation","important","experiments","demonstrates","convolutional","diagnosis","recognition","benchmark","intensive","competition","effectively","facilitate","attracted","desirable","autoimmune","components","efficiency","adaptability","classification","attention","outperform","entailment","relations","encourages","outperforms","sentences","automatically","furthermore","capabilities","performance","differentiable","demonstrating","qualitative","reasoning","determine","recognizing","mechanism","similarity","engineered","pipelines","processing","classifiers","entailments","substantial","classifier","employing","approaches","representations","ucfsports","designing","representation","magnitude","computation","activities","generated","prediction","challenging","predicting","corresponding","meaningful","basketball","experimental","generalize","containing","understanding","incorporating","geometric","information","densities","significant","exclusively","environmental","detecting","modelling","photogrammetric","photogrammetry","techniques","accuracies","monocular","companies","inspection","progresses","estimation","respectively","extraction","inference","pathologies","recurrent","functionality","application","minimally","diagnostic","evaluations","translational","converting","trajectories","controlled","rotational","endoscopy","operations","detection","intuitive","technology","estimates","following","supervision","relationships","situations","subproblems","supervised","plausible","baselines","particular","throughout","algorithms","consensus","computing","qualitatively","compromising","selection","identifying","technique","computational","clustering","considering","diversity","generating","frequency","judiciously","addresses","overheads","unnecessary","prioritize","representative","intelligence","partitions","transformations","statistical","invariances","visualizing","incorporate","introduce","explicitly","generative","architecture","rotations","adversarial","translations","parametrize","probability","initialized","essential","incapable","intriguingly","distribution","condition","achieving","exponential","analytically","initialization","vanishing","dependence","orthogonal","gradients","dramatically","concentrate","consideration","demonstrate","nonlinear","controlling","empirically","nonlinearity","consistently","explosion","sigmoidal","dynamical","integrate","transform","resurgence","appealing","localization","illumination","assumption","investigation","popularity","consistency","environments","conditions","competitive","improvements","photometric","robustness","previously","available","increasing","appearance","implementation","correspond","underlying","availability","conventional","relocalization","preliminary","canonical","synthetic","applications","illustrated","performances","demonstrated","intuition","asymptotic","resulting","collapses","practical","suggesting","parametrization","improvement","surprisingly","corrective","importance","theoretical","dimensional","inconsistent","algorithm","diffusion","arguments","requirements","optimization","restriction","splitting","inequality","denoising","compression","convergence","minimization","parameter","quantitatively","simulator","multivariate","reproduce","si ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	neuroscientists
# 	biophysical
# 	matchings
# 	eigenstructures
# 	reinterpret
# 	determinants
# 	discretizations
# 	decomposability
# 	inferential
# 	emphdirectly
# 	boundedness
# 	complexes
# 	electrocardiogram
# 	dermatological
# 	unavoidably
# 	hypernetworks
# 	discourages
# 	regularizes
# 	tailoring
# 	approachable
# Some words which never appear in Statistics papers:
# 	epithelial
# 	elaborates
# 	entailments
# 	ucfsports
# 	photogrammetric
# 	photogrammetry
# 	monocular
# 	rotational
# 	endoscopy
# 	prioritize
# 	sigmoidal
# 	illumination
# 	photometric
# 	relocalization
# 	transitional
# 	alternately
# 	retrained
# 	celebrity
# 	geolocation
# 	redundancies

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0905213709552804e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.775
